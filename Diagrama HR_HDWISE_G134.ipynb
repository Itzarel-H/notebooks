# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('seaborn-deep') #Estilo [default, classic'labdls-dark','grayscale', 'bmh', 'dark_background', 'ggplot', u'fivethirtyeight']
import pandas as pd
from astropy.io import ascii 
import matplotlib.colors

df1 = pd.read_csv("0.1Myr.csv")
df2 = pd.read_csv("0.5Myr.csv")
df3 = pd.read_csv("1Myrs.csv")
df4 = pd.read_csv("3Myrs.csv")
df5 = pd.read_csv("5Myr.csv")
df6 = pd.read_csv("10Myr.csv")
df7 = pd.read_csv("30Myr.csv")
df8 = pd.read_csv("100Myr.csv")
df9 = pd.read_csv("300Myr.csv")


x1 = df1['T'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y1 = df1['logL'].values.reshape(-1, 1)#df definido arriba
#plt.scatter(x1,y1,s=1, color="violet", label="0.1Myr")
plt.plot(x1,y1, color="lightblue", label="0.1Myr")


x2 = df2['T'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y2 = df2['logL'].values.reshape(-1, 1)#df definido arriba
#plt.scatter(x2,y2,s=1,color="g", label="0.5Myr")
plt.plot(x2,y2, color="mediumaquamarine", label="0.5Myr")


x3 = df3['T'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y3 = df3['logL'].values.reshape(-1, 1)#df definido arriba
#plt.scatter(x3,y3,s=1,color="b", label="1Myr")
plt.plot(x3,y3, color="aquamarine", label="1Myr")


x4 = df4['T'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y4 = df4['logL'].values.reshape(-1, 1)#df definido arriba
#plt.scatter(x4,y4,s=1,color="orange", label="3Myr")
plt.plot(x4,y4, color="lightsteelblue", label="3Myr")


x5 = df5['T'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y5 = df5['logL'].values.reshape(-1, 1)#df definido arriba
#plt.scatter(x5,y5,s=1,color="c",label="5Myr")
plt.plot(x5,y5, color="cadetblue", label="5Myr")

x6 = df6['T'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y6 = df6['logL'].values.reshape(-1, 1)#df definido arriba
#plt.scatter(x6,y6,s=1,color="yellow", label="10Myr")
plt.plot(x6,y6, color="steelblue", label="10Myr")


x7 = df7['T'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y7 = df7['logL'].values.reshape(-1, 1)#df definido arriba
#plt.scatter(x7,y7,s=1, color="b", label="30Myr")
plt.plot(x7,y7, color="royalblue", label="30Myr")


x8 = df8['T'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y8 = df8['logL'].values.reshape(-1, 1)#df definido arriba
#plt.scatter(x8,y8,s=1,color="gold", label="100Myr")
plt.plot(x8,y8, color="blue", label="100Myr")

x9 = df9['T'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y9 = df9['logL'].values.reshape(-1, 1)#df definido arriba
#plt.scatter(x9,y9,s=1,color="lightgreen", label="300Myr")
plt.plot(x9,y9, color="midnightblue", label="300Myr")



dfa = pd.read_csv("masa0.1.csv")
dfb = pd.read_csv("masa0.203.csv")
dfc = pd.read_csv("masa0.302.csv")
dfd = pd.read_csv("masa0.6.csv")
dfe = pd.read_csv("masa0.8.csv")
dff = pd.read_csv("masa1.0.csv")
dfg = pd.read_csv("masa2.0.csv")
dfh = pd.read_csv("masa3.0.csv")
dfi = pd.read_csv("masa5.2.csv")
dfj = pd.read_csv("masa6.0.csv")


xa = dfa['T'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
ya = dfa['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(xa,ya,s=0.1#label="0.1M"
           )
plt.plot(xa,ya,"--",linewidth=1, color="black")

xb = dfb['T'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
yb = dfb['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(xb,yb,s=0.1,#label="0.2M"
           )
plt.plot(xb,yb, "--",linewidth=1, color="black")

xc = dfc['T'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
yc = dfc['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(xc,yc,s=0.1,#label="0.4M"
           )
plt.plot(xc,yc, "--",linewidth=1, color="black")

xd = dfd['T'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
yd = dfd['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(xd,yd,s=0.1,#label="0.6M"
           )
plt.plot(xd,yd, "--",linewidth=1, color="black")

xe = dfe['T'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
ye = dfe['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(xe,ye,s=0.1,#label="0.8M"
           )
plt.plot(xe,ye, "--",linewidth=1, color="black")

xf = dff['T'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
yf = dff['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(xf,yf,s=0.1,#label="1M"
           )
plt.plot(xf,yf, "--", linewidth=1, color="black")


cygnus = pd.read_csv("HDWISE_G134.csv")
xcg = cygnus['mean_Teff'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
ycg = cygnus['lgL'].values.reshape(-1, 1)#df definido arriba
zcg  = cygnus['mean_Logg'].values.reshape(-1, 1)
plt.scatter(xcg,ycg,s=9, color="red", alpha=0.1, label="HDWISE_G134")


#s = plt.scatter(xcg,ycg, c=xcg, cmap='jet_r')
#c = plt.colorbar()

plt.legend(loc='lower left')
plt.xlim(7000, 2800)
plt.ylim(-3, 3)

plt.scatter(xcg,ycg,zcg, c=zcg, cmap='jet_r', vmin=3.4, vmax=4.8)
plt.xlabel("Temperatura [K]", size = 15,)
plt.ylabel("Luminosity log(L/$L_{\odot}$)", size = 15)
plt.colorbar(label="mean_Logg")
plt.title("HDWISE_G134", 
           fontdict={'family': 'serif', 
                    'color' : 'black',
                    'weight': 'bold',
                    'size': 18})
#plt.grid(color='k', linestyle='dotted', linewidth=1)



plt.savefig("Cygnus_HDWISE_G134 _Diagrama_HR.png")
plt.savefig("Cygnus_HDWISE_G134_Diagrama_HR.jpg")
