# %%
"""
a. Haz un diagrama Logg vs LogTeff y Luminosidad vs Log Teff, como los 
que hiciste en topcat.
b. Carga las curvas de masa constante que hicise con topcat al principio de la tarea
y graficalas en tu diagrama

"""
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('seaborn-bright') #Estilo [default, classic'labdls-dark','grayscale', 'bmh', 'dark_background', 'ggplot', u'fivethirtyeight']
import pandas as pd
 
df = pd.read_csv("HDWISE_G134.csv")
print(df)

#Diagrama logg vs logteff
x = df['mean_Teff'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y = df['mean_Logg'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x,y)
plt.gca().invert_xaxis()
plt.xlabel("Mean Teff", size = 11,)
plt.ylabel("Mean Logg", size = 11)
plt.title("Teff vs Logg", 
          fontdict={'family': 'serif', 
                    'color' : 'black',
                    'weight': 'bold',
                    'size': 15})
plt.savefig("Teff vs Logg.png")

plt.legend(loc='lower left')
plt.gca().invert_xaxis()
# Out:
#                APOGEE_ID        RA      DEC  APOGEE_Net_Logg  mean_Logg  \
# 0     2M20405366+4157359  310.2236  41.9600           4.0998     3.9091
# 1     2M20245532+3910324  306.2305  39.1757           4.1926     4.2418
# 2     2M20391254+4213579  309.8023  42.2328           4.2101     4.1937
# 3     2M20362089+4058584  309.0871  40.9829           1.6788     1.6553
# 4     2M20312695+4110130  307.8623  41.1703           4.3906     4.1348
# ...                  ...       ...      ...              ...        ...
# 1392  2M20315694+4131478  307.9873  41.5300           4.4401     4.4332
# 1393  2M20215160+3959496  305.4650  39.9971           4.5481     4.5442
# 1394  2M20313853+4152584  307.9106  41.8829           4.3927     4.4189
# 1395  2M20421727+4129039  310.5720  41.4844           4.4323     4.4595
# 1396  2M20235622+3757209  305.9843  37.9558           4.1048     4.2031
#
#       sd_Logg  APOGEE_Net_Teff  mean_Teff   sd_Teff  APOGEE_Net_FeH  ...  \
# ...

# %%
#Diagrama loglvs logteff
x = df['logmeanTef'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y = df['lgL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x,y)
plt.gca().invert_xaxis()
plt.xlabel("Mean log(Teff)", size = 11,)
plt.ylabel("Mean log(L)", size = 11)
plt.title("Log (Teff) vs Log(L)", 
          fontdict={'family': 'serif', 
                    'color' : 'black',
                    'weight': 'bold',
                    'size': 15})
plt.savefig("Log (Teff) vs Log(L).png")

plt.gca().invert_xaxis()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('seaborn-bright') #Estilo [default, classic'labdls-dark','grayscale', 'bmh', 'dark_background', 'ggplot', u'fivethirtyeight']
import pandas as pd

df1 = pd.read_csv("0.1Myr.csv")
df2 = pd.read_csv("0.5Myr.csv")
df3 = pd.read_csv("1Myrs.csv")
df4 = pd.read_csv("3Myrs.csv")
df5 = pd.read_csv("5Myr.csv")
df6 = pd.read_csv("10Myr.csv")
df7 = pd.read_csv("30Myr.csv")
df8 = pd.read_csv("100Myr.csv")


x1 = df1['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y1 = df1['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x1,y1,s=3,label="0.1Myr")


x2 = df2['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y2 = df2['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x2,y2,s=3,label="0.5Myr")


x3 = df3['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y3 = df3['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x3,y3,s=3,label="1Myr")

x4 = df4['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y4 = df4['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x4,y4,s=3,label="3Myr")

x5 = df5['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y5 = df5['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x5,y5,s=3,label="5Myr")

x6 = df6['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y6 = df6['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x6,y6,s=3,label="10Myr")

x7 = df7['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y7 = df7['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x7,y7,s=3,label="30Myr")

x8 = df8['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y8 = df8['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x8,y8,s=3,label="100Myr")

plt.legend(loc='upper left')


plt.gca().invert_xaxis()
plt.xlabel("Temperatura log(Teff)", size = 11,)
plt.ylabel("Luminosity log(L)", size = 11)
plt.title("Temperatura vs Luminosidad", 
          fontdict={'family': 'serif', 
                    'color' : 'black',
                    'weight': 'bold',
                    'size': 15})

plt.savefig("Temperatura vs Luminosidad.png")

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('seaborn-bright') #Estilo [default, classic'labdls-dark','grayscale', 'bmh', 'dark_background', 'ggplot', u'fivethirtyeight']
import pandas as pd


df1 = pd.read_csv("0.1Myr.csv")
df2 = pd.read_csv("0.5Myr.csv")
df3 = pd.read_csv("1Myrs.csv")
df4 = pd.read_csv("3Myrs.csv")
df5 = pd.read_csv("5Myr.csv")
df6 = pd.read_csv("10Myr.csv")
df7 = pd.read_csv("30Myr.csv")
df8 = pd.read_csv("100Myr.csv")
df9 = pd.read_csv("300Myr.csv")


x1 = df1['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y1 = df1['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x1,y1,s=1, color="violet", label="0.1Myr")


x2 = df2['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y2 = df2['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x2,y2,s=1,color="g", label="0.5Myr")


x3 = df3['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y3 = df3['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x3,y3,s=1,color="b", label="1Myr")

x4 = df4['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y4 = df4['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x4,y4,s=1,color="orange", label="3Myr")

x5 = df5['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y5 = df5['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x5,y5,s=1,color="c",label="5Myr")

x6 = df6['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y6 = df6['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x6,y6,s=1,color="yellow", label="10Myr")

x7 = df7['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y7 = df7['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x7,y7,s=1, color="darkgreen", label="30Myr")

x8 = df8['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y8 = df8['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x8,y8,s=1,color="gold", label="100Myr")

x9 = df9['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
y9 = df9['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(x9,y9,s=1,color="b", label="300Myr")


dfa = pd.read_csv("masa0.1.csv")
dfb = pd.read_csv("masa0.203.csv")
dfc = pd.read_csv("masa0.401.csv")
dfd = pd.read_csv("masa0.6.csv")
dfe = pd.read_csv("masa0.8.csv")
dff = pd.read_csv("masa1.0.csv")
dfg = pd.read_csv("masa2.0.csv")
dfh = pd.read_csv("masa3.0.csv")
dfi = pd.read_csv("masa5.2.csv")
dfj = pd.read_csv("masa6.0.csv")


xa = dfa['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
ya = dfa['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(xa,ya,s=4,#label="0.1M"
           )
plt.plot(xa,ya, color="black")

xb = dfb['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
yb = dfb['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(xb,yb,s=4,#label="0.2M"
           )
plt.plot(xb,yb, color="black")

xc = dfc['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
yc = dfc['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(xc,yc,s=4,#label="0.4M"
           )
plt.plot(xc,yc, color="black")

xd = dfd['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
yd = dfd['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(xd,yd,s=4,#label="0.6M"
           )
plt.plot(xd,yd, color="black")

xe = dfe['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
ye = dfe['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(xe,ye,s=4,#label="0.8M"
           )
plt.plot(xe,ye, color="black")

xf = dff['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
yf = dff['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(xf,yf,s=4,#label="1M"
           )
plt.plot(xf,yf, color="black")

xg = dfg['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
yg = dfg['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(xg,yg,s=4,#label="2M"
           )
plt.plot(xg,yg, color="black")

xh = dfh['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
yh = dfh['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(xh,yh,s=4,#label="3M"
           )
plt.plot(xh,yh, color="black")

xi = dfi['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
yi = dfi['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(xi,yi,s=4,#label="5M"
           )
plt.plot(xi,yi, color="black")

xj = dfj['logTe'].values.reshape(-1, 1) # necesitamos un array de 2D para SkLearn
yj = dfj['logL'].values.reshape(-1, 1)#df definido arriba
plt.scatter(xj,yj,s=4,#label="6M"
           )
plt.plot(xj,yj, color="black")

plt.legend(loc='lower left')
plt.gca().invert_xaxis()
plt.xlabel("Temperatura log(Teff)", size = 15,)
plt.ylabel("Luminosity log(L)", size = 15)
plt.title("Curvas de masa y edad", 
          fontdict={'family': 'serif', 
                    'color' : 'black',
                    'weight': 'bold',
                    'size': 25})

plt.savefig("Curvas edad masa.png")
